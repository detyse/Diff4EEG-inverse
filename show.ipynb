# %% [markdown]
# ## Show generation

# %%
# %load_ext autoreload
# %autoreload 2

import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from utils.utils import frequency_domain

# result_path = '/home/wyl/projects/_BSS_hijack/result/generate'
data_path = '/home/wyl/projects/_BSS_hijack/result/generate/output_20230412_020637/result.npy' # 'data_file/data_name'
samples = np.load(data_path)

print(samples.shape)

fig, ax = plt.subplots(5, 3, figsize=(20, 10))
for row in range(5):
    data = samples[row]
    for col in range(3):
        ax[row, col].plot(samples[row, col])


# figure 1:
# Out:
# (64, 3, 512)

# %%
import matplotlib.pyplot as plt
from utils.utils import TSNE

sample_from_real_data = 1
generatived_data = 2

# %% [markdown]
# ## Show hijack

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import argparse

# %% [markdown]
# # ICA

# %%
from utils.utils import ICA
from datasets.datasets import perturbed_test_dataset, separated_test_dataset
